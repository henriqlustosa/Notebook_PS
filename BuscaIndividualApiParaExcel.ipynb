# %%
## Importação das bibliotecas utilizadas no código fonte
import requests
import json
import pandas as pd

# %%
# Endpoints pordução do SGH

#Profissionais Médicos que deram baixa no SGH
res_pac = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/pacientesacolhidos/2022-12-01/2023-03-31')

# %%
# Carregando os dados 'json' para um tipo dicionário

#Profissionais Médicos que deram baixa no SGH
response_pac = json.loads(res_pac.text)

# %%
# Criando os DataFrames a partir dos dicionários

#Profissionais Médicos que deram baixa no SGH
df_pac =  pd.DataFrame.from_dict(response_pac)

# %%
# Profissional 

# determining the name of the file
file_paciente = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\Pasta\Paciente_Acolhido_Geral_Marco.xlsx'
  
# saving the excel
df_pac.to_excel(file_paciente)

# %%
# Endpoints pordução do SGH

#Profissionais Médicos que deram baixa no SGH
res_prof = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/profissionais/2022-12-01/2023-04-06')

# %%
# Endpoints produção do SGH

#Pacientes atendidos pelo PS
res_pac = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/pacientesacolhidos/2023-03-01/2023-03-31')

# %%
# Carregando os dados 'json' para um tipo dicionário

#Pacientes atendidos pelo PS
response_pac = json.loads(res_pac.text)

# %%
# Criando os DataFrames a partir dos dicionários

#Pacientes atendidos pelo PS
df_pac =  pd.DataFrame.from_dict(response_pac)

# %%
# importacao de bibliotecas
import pandas as pd
from unidecode import unidecode

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.18.5

# %%
# Importacao da biblioteca sqlalchemy
from sqlalchemy import create_engine

# %%
## Conexão com a base de dados postgree

import pyodbc as podbc

cnxn = podbc.connect("Driver={SQL Server Native Client 11.0};Server=hspmins18;Database=hspmRelatorioPs;uid=hspmApp;pwd=SoundG@rden=1")

# %%
## Acesso a base de dados

sql = "SELECT * FROM [hspmRelatorioPs].[dbo].[Paciente_Acolhido]"
data_sql_server_pac = pd.read_sql(sql,cnxn)

# %%
data_sql_server_pac.head()
# Out:
#    prontuario                       nomePaciente dataNascimento cns  \
# 0           1  CHRISTIAN ANDREWS GAGLIANI HESSEL     2000-01-27   0
# 1           3                 CIBELE COSTA MEIRA     1984-11-13   0
# 2           4            ISABEL PADELLA MARTINEZ     1960-01-09   0
# 3           5           M.A RUTE ARAUJO DE ABREU     1998-04-06   0
# 4           7      MARIA HELENA PRETE DE ALMEIDA     1938-03-05   0
#
#              rg cpf sexo  idade    raca                             mae  \
# 0  39.149.435-1   0    M     23  Branca  VANESSA KAREN GAGLIONI CURILLO
# 1          None   0    F     38    None        INACIA MARIA COSTA MEIRA
# 2          None   0    F     63    None            LUIZA PADELLA GARCIA
# 3          None   0    F     24  Branca        MARIA DO CARMO DE ARAUJO
# 4          None   0    F     84    None         ANTONIA MONTANARI PRETE
#
#                       pai email tipoPaciente       rf  ddd_foneResidencial  \
# 0   DALZI DE BORBA HESSEL  None     Munícipe        0                 11.0
# 1      LUIZ BATISTA MEIRA  None     Servidor  8873488                 83.0
# 2  MANOEL MARTINEZ GARCIA  None     Servidor  5191602                 11.0
# 3                    None  None     Munícipe        0                 11.0
# 4           ANTONIO PRETE  None     Munícipe        0                 11.0
#
#    ddd_foneComercial  ddd_foneRecado  foneResidencial  foneComercial  \
# 0                NaN             NaN      946996967.0            NaN
# 1                NaN             NaN      991367874.0            NaN
# 2                NaN             NaN      953551182.0            NaN
# 3                NaN            11.0      976505190.0            NaN
# 4                NaN             NaN      994444202.0            NaN
#
#     foneRecado
# 0          NaN
# 1          NaN
# 2          NaN
# 3  966040207.0
# 4          NaN

# %%
data_sql_server_pac.shape
# Out:
# (11357, 20)

# %%
result = pd.merge(data_sql_server_pac, df_pac, on="prontuario",how="outer",indicator=True)

# %%
result.head()
# Out:
#    prontuario                     nomePaciente_x dataNascimento_x cns_x  \
# 0           1  CHRISTIAN ANDREWS GAGLIANI HESSEL       2000-01-27     0
# 1           3                 CIBELE COSTA MEIRA       1984-11-13     0
# 2           4            ISABEL PADELLA MARTINEZ       1960-01-09     0
# 3           5           M.A RUTE ARAUJO DE ABREU       1998-04-06     0
# 4           7      MARIA HELENA PRETE DE ALMEIDA       1938-03-05     0
#
#            rg_x cpf_x sexo_x  idade_x  raca_x                           mae_x  \
# 0  39.149.435-1     0      M     23.0  Branca  VANESSA KAREN GAGLIONI CURILLO
# 1          None     0      F     38.0    None        INACIA MARIA COSTA MEIRA
# 2          None     0      F     63.0    None            LUIZA PADELLA GARCIA
# 3          None     0      F     24.0  Branca        MARIA DO CARMO DE ARAUJO
# 4          None     0      F     84.0    None         ANTONIA MONTANARI PRETE
#
#    ... email_y tipoPaciente_y rf_y ddd_foneResidencial_y  ddd_foneComercial_y  \
# 0  ...     NaN            NaN  NaN                   NaN                  NaN
# 1  ...     NaN            NaN  NaN                   NaN                  NaN
# 2  ...     NaN            NaN  NaN                   NaN                  NaN
# 3  ...     NaN            NaN  NaN                   NaN                  NaN
# 4  ...     NaN            NaN  NaN                   NaN                  NaN
#
#    ddd_foneRecado_y  foneResidencial_y  foneComercial_y  foneRecado_y  \
# 0               NaN                NaN              NaN           NaN
# 1               NaN                NaN              NaN           NaN
# 2               NaN                NaN              NaN           NaN
# 3               NaN                NaN              NaN           NaN
# 4               NaN                NaN              NaN           NaN
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only
#
# [5 rows x 40 columns]

# %%
result=result[result['_merge']=='right_only']

# %%
result.shape
# Out:
# (4377, 40)

# %%
df_pac.head()
# Out:
#    prontuario                      nomePaciente dataNascimento  \
# 0       10025           ANTONIA MARCELINO SERRA     13/06/1934
# 1       11585          DARCY DE LOURDES CARDOSO     27/10/1936
# 2       11676  VILMA VALENTIM FONTES MAIA ROCHA     11/04/1945
# 3       15628    MARIA DO CARMO SANTOS DA SILVA     08/09/1937
# 4       19521            ETELVINA JULIA PADETTI     08/04/1936
#
#                cns         rg          cpf sexo  idade    raca  \
# 0  898000064478787  138565223  25157303882    F     88  Branca
# 1                0                       0    F     86
# 2  898001418455913  2760002-6   8398766883    F     78
# 3  801434175371546  167258205   5265027890    F     85  Branca
# 4  801440482745016   24994534  12988443807    F     87  Branca
#
#                          mae                         pai       email  \
# 0  MARIA APARECIDO MARCELINO  JOAQUIM MARCELINO DA SILVA
# 1  ANTONIA PEREIRA LOCATELLI           ANTONIO LOCATELLI        None
# 2    MARINHA VALENTIM FONTES     ARLINDO FERNNDES FONTES  NAO POSSUI
# 3      MARIA JOSE DOS SANTOS       JOSE BISPO DOS SANTOS
# 4     ROSINA VIEIRA DA ROCHA       OZORIO JULIO DA CUNHA
#
#   tipoPaciente        rf ddd_foneResidencial ddd_foneComercial ddd_foneRecado  \
# 0     Servidor    267744                  11              None             11
# 1     Servidor    178306                  11              None           None
# 2     Servidor    115185                  11                11             11
# 3     Servidor  13593300                  11              None             11
# 4     Servidor   4511689                  11              None             11
#
#   foneResidencial foneComercial foneRecado
# 0       986887594                971432188
# 1        24224027          None       None
# 2        23080104     970631476  948944892
# 3       988186794                994727158
# 4        39827475                974651709

# %%
result.head()
# Out:
#        prontuario nomePaciente_x dataNascimento_x cns_x rg_x cpf_x sexo_x  \
# 11357       20560            NaN              NaN   NaN  NaN   NaN    NaN
# 11358       45393            NaN              NaN   NaN  NaN   NaN    NaN
# 11359       54973            NaN              NaN   NaN  NaN   NaN    NaN
# 11360       55079            NaN              NaN   NaN  NaN   NaN    NaN
# 11361       65946            NaN              NaN   NaN  NaN   NaN    NaN
#
#        idade_x raca_x mae_x  ...                           email_y  \
# 11357      NaN    NaN   NaN  ...                              None
# 11358      NaN    NaN   NaN  ...             NEUSABOMFIM@GMAIL.COM
# 11359      NaN    NaN   NaN  ...
# 11360      NaN    NaN   NaN  ...                              None
# 11361      NaN    NaN   NaN  ...  ELIZABETECAMARGO.SOUZA@GMAIL.COM
#
#       tipoPaciente_y     rf_y ddd_foneResidencial_y  ddd_foneComercial_y  \
# 11357     Dependente  4478851                    11                 None
# 11358       Servidor   258393                    11                   11
# 11359       Servidor  4518403                    11                 None
# 11360       Servidor        0                  None                 None
# 11361       Servidor   240486                    11                 None
#
#        ddd_foneRecado_y  foneResidencial_y  foneComercial_y  foneRecado_y  \
# 11357              None           22413194             None          None
# 11358                11           56692920        994630907     993656010
# 11359                11          952148625                       46774533
# 11360              None           39826375             None          None
# 11361                11          939544522                      978450741
#
#            _merge
# 11357  right_only
# 11358  right_only
# 11359  right_only
# 11360  right_only
# 11361  right_only
#
# [5 rows x 40 columns]

# %%
#Determinando o nome do arquivo
file_name_ficha = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\Pasta\Paciente_Acolhido_03_2023.xlsx'
  
# Salvando o excel
result.to_excel(file_name_ficha)
