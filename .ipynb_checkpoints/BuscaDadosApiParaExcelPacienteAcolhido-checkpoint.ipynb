# %%
## Importação das Bibliotecas utilizadas neste Fonte
import requests
import json 
import pandas as pd

# %%
# Endpoints para o consumo de dados do banco de dados de produção do SGH

#Fichas dos Pacientes Acolhidos
res_ficha_pac_acolhido = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/fichapacientesacolhidos/2022-12-01/2023-01-31')

#Pacientes Acolhido
res_pac_acolhido = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/pacientesacolhidos/2022-12-01/2023-01-31')

#Profissionais do Guichê
res_prof_guiche = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/profissionaisguiche/2022-12-01/2023-01-31')

#Endereços dos Pacientes Acolhidos
res_ender_pac_acolhido = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/enderecofichapacientesacolhidos/2022-12-01/2023-01-31')

# %%
# Carregando os dados 'json' para um tipo dicionário

#Fichas dos Pacientes Acolhidos
response_ficha_pac_acolhido = json.loads(res_ficha_pac_acolhido.text)

#Pacientes Acolhido
response_pac_acolhido = json.loads(res_pac_acolhido.text)

#Profissionais do Guichê
response_prof_guiche = json.loads(res_prof_guiche.text)

#Endereços dos Pacientes Acolhidos
response_ender_acolhido = json.loads(res_ender_pac_acolhido.text)

# %%
# Criando os DataFrames a partir dos dicionários

#Fichas dos Pacientes Acolhidos
df_ficha_pac_acolhido =  pd.DataFrame.from_dict(response_ficha_pac_acolhido)

#Pacientes Acolhido
df_pac_acolhido =  pd.DataFrame.from_dict(response_pac_acolhido)

#Profissionais do Guichê
df_prof_guiche =  pd.DataFrame.from_dict(response_prof_guiche)

#Endereços dos Pacientes Acolhidos
df_ender_pac_acolhido =  pd.DataFrame.from_dict(response_ender_acolhido)

# %%
#Apresentação dos dados de cada DataFrame

#Fichas dos Pacientes Acolhidos
df_ficha_pac_acolhido.head()
# Out:
#    prontuario         data_acolhimento status_ficha origem_paciente  \
# 0     3758257   2023-01-27 11:33:06.35  ENC TRIAGEM  MEIOS PRÓPRIOS
# 1     2852168  2023-01-27 11:28:45.897  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2     3866845   2023-01-27 11:27:02.69  ENC TRIAGEM  MEIOS PRÓPRIOS
# 3     3884392  2023-01-27 11:24:47.208  ENC TRIAGEM  MEIOS PRÓPRIOS
# 4    11567369  2023-01-27 11:23:19.315  ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                  queixa informacoes_complementares usuario_acolhimento  \
# 0                 queda                       None             H013147
# 1  DOR NO OMBRO\r\n\r\n                       None             H010269
# 2         dor abdominal                       None             H010350
# 3        dor nas costas                       None             H010350
# 4                 gripe                       None             H013147
#
#                                                nome
# 0                                 JOSE LOPES VIEIRA
# 1                       MARIA ADELIA TEIXEIRA LEITE
# 2                    VALDA MARIA GOMES VIEGAS BRITO
# 3                       GLORIA WATANABE - ATUALIZAR
# 4  GUSTAVO BISPO ALVES MARQUES DIAS    -12-05-2023-

# %%
#Fichas dos Pacientes Acolhidos com o campo 'nome do profissional do guichê' 
df_ficha_pac_acolhido_prof_guiche = pd.merge(df_ficha_pac_acolhido, df_prof_guiche, how='inner', on = 'usuario_acolhimento')

# %%
# Apresentação dos dados com o nome do profissional
df_ficha_pac_acolhido_prof_guiche.head()
# Out:
#    prontuario         data_acolhimento status_ficha origem_paciente  \
# 0     3758257   2023-01-27 11:33:06.35  ENC TRIAGEM  MEIOS PRÓPRIOS
# 1    11567369  2023-01-27 11:23:19.315  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2     4408241   2023-01-27 11:11:05.53  ENC TRIAGEM  MEIOS PRÓPRIOS
# 3    10756468  2023-01-27 11:07:31.859  ENC TRIAGEM  MEIOS PRÓPRIOS
# 4    10168631  2023-01-27 11:02:54.287  ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                   queixa informacoes_complementares usuario_acolhimento  \
# 0                  queda                       None             H013147
# 1                  gripe                       None             H013147
# 2                  gripe                       None             H013147
# 3                  tosse                       None             H013147
# 4  sangramento no ouvido                       None             H013147
#
#                                                nome      nome_profissional
# 0                                 JOSE LOPES VIEIRA  SORAIA CRISTINA MARIA
# 1  GUSTAVO BISPO ALVES MARQUES DIAS    -12-05-2023-  SORAIA CRISTINA MARIA
# 2                              EUNICE DIAS DE SOUZA  SORAIA CRISTINA MARIA
# 3                                 RONEI GOMES LEITE  SORAIA CRISTINA MARIA
# 4                FELIPE JOSE SAGRADO DA CONCEICAO *  SORAIA CRISTINA MARIA

# %%
#Relatório de produtividade - alteração realizada para medir a produtividade por hora

# %%
# Informações do data_frame, verificando campos nulos
df_ficha_pac_acolhido_prof_guiche.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9126 entries, 0 to 9125
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   prontuario                  9126 non-null   int64
#  1   data_acolhimento            9126 non-null   object
#  2   status_ficha                9126 non-null   object
#  3   origem_paciente             9126 non-null   object
#  4   queixa                      9126 non-null   object
#  5   informacoes_complementares  126 non-null    object
#  6   usuario_acolhimento         9126 non-null   object
#  7   nome                        9126 non-null   object
#  8   nome_profissional           9126 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 713.0+ KB

# %%
# Mudança do tipo do campo "data_acolhimento" para datetime
 
df_ficha_pac_acolhido_prof_guiche["data_acolhimento"] = pd.to_datetime(df_ficha_pac_acolhido_prof_guiche["data_acolhimento"])

# %%
# Visualização das informações atualizadas
df_ficha_pac_acolhido_prof_guiche.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9126 entries, 0 to 9125
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   prontuario                  9126 non-null   int64
#  1   data_acolhimento            9126 non-null   datetime64[ns]
#  2   status_ficha                9126 non-null   object
#  3   origem_paciente             9126 non-null   object
#  4   queixa                      9126 non-null   object
#  5   informacoes_complementares  126 non-null    object
#  6   usuario_acolhimento         9126 non-null   object
#  7   nome                        9126 non-null   object
#  8   nome_profissional           9126 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 713.0+ KB

# %%
# Valores do data_frame 
df_ficha_pac_acolhido_prof_guiche.head()
# Out:
#    prontuario        data_acolhimento status_ficha origem_paciente  \
# 0     3758257 2023-01-27 11:33:06.350  ENC TRIAGEM  MEIOS PRÓPRIOS
# 1    11567369 2023-01-27 11:23:19.315  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2     4408241 2023-01-27 11:11:05.530  ENC TRIAGEM  MEIOS PRÓPRIOS
# 3    10756468 2023-01-27 11:07:31.859  ENC TRIAGEM  MEIOS PRÓPRIOS
# 4    10168631 2023-01-27 11:02:54.287  ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                   queixa informacoes_complementares usuario_acolhimento  \
# 0                  queda                       None             H013147
# 1                  gripe                       None             H013147
# 2                  gripe                       None             H013147
# 3                  tosse                       None             H013147
# 4  sangramento no ouvido                       None             H013147
#
#                                                nome      nome_profissional
# 0                                 JOSE LOPES VIEIRA  SORAIA CRISTINA MARIA
# 1  GUSTAVO BISPO ALVES MARQUES DIAS    -12-05-2023-  SORAIA CRISTINA MARIA
# 2                              EUNICE DIAS DE SOUZA  SORAIA CRISTINA MARIA
# 3                                 RONEI GOMES LEITE  SORAIA CRISTINA MARIA
# 4                FELIPE JOSE SAGRADO DA CONCEICAO *  SORAIA CRISTINA MARIA

# %%
# Contagem de produtividade por fichas abertas por hora
dc_contagem_por_hora = df_ficha_pac_acolhido_prof_guiche.resample('H', on='data_acolhimento').prontuario.count()

# %%
# Dataframe de produtividade por fichas abertas por hora 
df_contagem_por_hora = dc_contagem_por_hora.to_frame()

# %%
# Acrescentando os campos data e hora separadamente no dataframe de produtividade
df_contagem_por_hora['data'] = [d.date() for d in df_contagem_por_hora.index]
df_contagem_por_hora['hora'] = [d.time() for d in df_contagem_por_hora.index]

# %%
# Apresentação dos dados das primeiras 24h do dataframe
df_contagem_por_hora.head(24)
# Out:
#                      prontuario        data      hora
# data_acolhimento
# 2022-12-01 01:00:00           1  2022-12-01  01:00:00
# 2022-12-01 02:00:00           0  2022-12-01  02:00:00
# 2022-12-01 03:00:00           1  2022-12-01  03:00:00
# 2022-12-01 04:00:00           1  2022-12-01  04:00:00
# 2022-12-01 05:00:00           1  2022-12-01  05:00:00
# 2022-12-01 06:00:00           5  2022-12-01  06:00:00
# 2022-12-01 07:00:00          10  2022-12-01  07:00:00
# 2022-12-01 08:00:00          14  2022-12-01  08:00:00
# 2022-12-01 09:00:00          21  2022-12-01  09:00:00
# 2022-12-01 10:00:00          26  2022-12-01  10:00:00
# 2022-12-01 11:00:00          22  2022-12-01  11:00:00
# 2022-12-01 12:00:00          22  2022-12-01  12:00:00
# 2022-12-01 13:00:00          28  2022-12-01  13:00:00
# 2022-12-01 14:00:00          20  2022-12-01  14:00:00
# 2022-12-01 15:00:00          14  2022-12-01  15:00:00
# 2022-12-01 16:00:00          18  2022-12-01  16:00:00
# 2022-12-01 17:00:00          13  2022-12-01  17:00:00
# 2022-12-01 18:00:00           1  2022-12-01  18:00:00
# 2022-12-01 19:00:00           5  2022-12-01  19:00:00
# 2022-12-01 20:00:00           4  2022-12-01  20:00:00
# 2022-12-01 21:00:00           4  2022-12-01  21:00:00
# 2022-12-01 22:00:00           3  2022-12-01  22:00:00
# 2022-12-01 23:00:00           0  2022-12-01  23:00:00
# 2022-12-02 00:00:00           2  2022-12-02  00:00:00

# %%
#Determinando o nome do arquivo
file_name_ficha = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\SQL_Server\Produtividade\FichaPacientesAcolhidos_Produtividade.xlsx'
  
# Salvando o excel
df_contagem_por_hora.to_excel(file_name_ficha)

# %%
# Relatório - Pacientes Acolhidos
# Base de Dados para geração dos arquivos das tabelas dos Pacientes Acolhidos

# %%
# Fichas dos Pacientes Acolhidos
# determining the name of the file

file_name_ficha = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\SQL_Server\PacienteAcolhido\FichaPacientesAcolhidos.xlsx'

# saving the excel

df_ficha_pac_acolhido.to_excel(file_name_ficha)

# %%
# Endereços dos Pacientes Acolhidos

# determining the name of the file

file_name_endereco = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\SQL_Server\PacienteAcolhido\EnderecosDePacientesAcolhidos.xlsx'

# saving the excel

df_ender_pac_acolhido.to_excel(file_name_endereco)

# %%
# Pacientes Acolhidos

# determining the name of the file

file_name_paciente = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\SQL_Server\PacienteAcolhido\PacientesAcolhidos.xlsx'

# saving the excel

df_pac_acolhido.to_excel(file_name_paciente)

# %%
#Profissionais do Guichê

# determining the name of the file

file_name_paciente = r'G:\OneDrive - Default Directory\OneDrive - rede.sp\WorkSpace_PS\Arquivos_Excel\SQL_Server\PacienteAcolhido\ProfissionalGuiche.xlsx'

# saving the excel

df_prof_guiche.to_excel(file_name_paciente)
