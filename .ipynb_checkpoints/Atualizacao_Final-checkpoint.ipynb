# %%
# importacao de bibliotecas
import pandas as pd
from unidecode import unidecode
import numpy as np
from sqlalchemy import create_engine

# %load_ext sql

# %%
# Buscar dados dos arquivos do excel

df_excel_total = pd.read_excel(r'G:\OneDrive - Default Directory\OneDrive - rede.sp\Arquivos_CCIH\ARQUIVOS_ORIGINAIS\Relatorio_CCIH_07_06_ate_30_07_2024.xlsx')

# %%
columns_to_drop = ['Unnamed: 0']

df_excel_total = df_excel_total.drop(columns_to_drop,errors='ignore', axis=1)
df_excel_total.shape[0]
# Out:
# 591

# %%
#Apresentacao dos dados

df_excel_total.head()
# Out:
#   parametroDataInicial parametroDataFinal ParametroUsuarioLogado DataSistema  \
# 0           2024-06-07         2024-07-30          HENRIQLUSTOSA  2024-06-25
# 1           2024-06-07         2024-07-30          HENRIQLUSTOSA  2024-06-25
# 2           2024-06-07         2024-07-30          HENRIQLUSTOSA  2024-07-03
# 3           2024-06-07         2024-07-30          HENRIQLUSTOSA  2024-06-17
# 4           2024-06-07         2024-07-30          HENRIQLUSTOSA  2024-06-17
#
#   Clinica            NomeClinica  NumeroPedido                NomePaciente  \
# 0    1PCH                 CHOQUE      10818020     ABRAO DOS SANTOS EMIDIO
# 1    1PCH                 CHOQUE      10833557     ABRAO DOS SANTOS EMIDIO
# 2    6URO  UROLOGIA_6º AND - AMB      10836216            ADALBERTO CORREA
# 3    6URO  UROLOGIA_6º AND - AMB      10828087  ADILSON ANTUNES BITENCOURT
# 4    6URO  UROLOGIA_6º AND - AMB      10828087  ADILSON ANTUNES BITENCOURT
#
#   DataNascimento                    Nome  \
# 0     1954-06-26  HEMOCULTURA 1º AMOSTRA
# 1     1954-06-26              UROCULTURA
# 2     1948-06-14              UROCULTURA
# 3     1947-01-21              UROCULTURA
# 4     1947-01-21              UROCULTURA
#
#                                            Resultado
# 0            Isolado [1]: Staphylococcus epidermidis
# 1  Isolado [1]: Klebsiella pneumoniae ssp pneumoniae
# 2  Isolado [1]: Klebsiella pneumoniae ssp pneumoniae
# 3                      Isolado [1]: Escherichia coli
# 4                    Isolado [2]: Candida tropicalis

# %%
# Busca dos resultados de exames positivados de MDR de com duas linhas no dataframe original
df_excel = df_excel_total
df_resultados_linha_2 = df_excel.loc[((df_excel['Resultado'] == 'Enterococcus resistente a glicopeptideos (VRE), consultar CCIH.') | (df_excel['Resultado'] == 'Cepa resistente a carbapenemicos, consultar CCIH.')| (df_excel['Resultado'] == 'Enterococcus Vanco Resistente (VRE), consultar CCIH.')| (df_excel['Resultado'] == 'Ampicilina - Resistente')) & (df_excel['NomePaciente'] == df_excel['NomePaciente'].shift(1))]

df_resultados_linha_1 = df_excel.loc[(df_resultados_linha_2.index - 1)]

# Alteração do índice no dataframe que buscou os dados do excel para substituição da linha 2 para a linhas 1
df_resultados_linha_2.index = df_resultados_linha_2.index - 1

df_resultados_linha_1['ComplementoResultado'] = df_resultados_linha_2.Resultado.values

df_resultados_linha_1.shape[0]
# Out:
# 43

# %%
# Busca dos resultados de exames positivados de MDR de com apenas 1 linha no dataframe original
df_excel_2 = df_excel_total

df_resultados_apenas_linha_1 = df_excel_2.loc[((df_excel_2['Resultado'] == 'Enterococcus resistente a glicopeptideos (VRE), consultar CCIH.') | (df_excel_2['Resultado'] == 'Cepa resistente a carbapenemicos, consultar CCIH.')| (df_excel_2['Resultado'] == 'Enterococcus Vanco Resistente (VRE), consultar CCIH.')| (df_excel_2['Resultado'] == 'Ampicilina - Resistente')) & (df_excel_2['NomePaciente'] != df_excel_2['NomePaciente'].shift(1))].copy()

df_resultados_apenas_linha_1['ComplementoResultado'] = df_resultados_apenas_linha_1['Resultado']

df_resultados_apenas_linha_1.loc[:, 'Resultado'] = np.nan

df_resultados_apenas_linha_1.shape[0]
# Out:
# 0

# %%
# Dataframe com todos os resultados de MDR positivados

df_resultados_excel = pd.concat([df_resultados_linha_1, df_resultados_apenas_linha_1], ignore_index=True)

# %%
## Conexão com a base de dados postgree

import pyodbc as podbc

cnxn = podbc.connect("Driver={SQL Server Native Client 11.0};Server=hspmins18;Database=Isolamento_Versao_2;uid=hspmApp;pwd=SoundG@rden=1")

# %%
## Acesso a base de dados

sql = "SELECT * FROM [Isolamento_Versao_2].[dbo].[CCIH] WHERE    [DataSistema] BETWEEN '2024-07-06' AND '2024-30-07' "
df_resultados_sql = pd.read_sql(sql,cnxn)
df_resultados_sql.shape[0]
# Out:
# <ipython-input-9-315c54a0ca55>:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_resultados_sql = pd.read_sql(sql,cnxn)
# 43

# %%
# from excel
# df_resultados_excel

# from data base 
# df_resultados_sql

df_resultados_inner_join = pd.merge(df_resultados_excel, df_resultados_sql, on=['NumeroPedido', 'Resultado'], how='inner')
df_resultados_inner_join.shape[0]
# Out:
# 43

# %%
# Perform a left join
df_merge_sql = pd.merge(df_resultados_sql, df_resultados_excel, on=['NumeroPedido', 'Resultado'], how='left', indicator=True)
df_merge_sql.shape[0]
# Out:
# 43

# %%
# Finding columns that contain '__y'
columns_to_drop_sql = [col for col in df_merge_sql.columns if '_y' in col]
# Adding another column to drop
additional_columns_sql = ['_merge'] 
# Append or extend the list with new column na
columns_to_drop_sql.extend(additional_columns_sql)


df_anti_join_sql= df_merge_sql[df_merge_sql['_merge'] == 'left_only'].drop(columns=columns_to_drop_sql)
df_anti_join_sql.shape[0]
# Out:
# 0

# %%
# Perform a left join
df_merge_excel = pd.merge(df_resultados_excel, df_resultados_sql, on=['NumeroPedido', 'Resultado'], how='left', indicator=True)
# Finding columns that contain '__y'
columns_to_drop_excel = [col for col in df_merge_sql.columns if '_y' in col]

# List of additional columns to drop
additional_columns_excel = ['_merge','posicao','Prontuario','id'] 
# Append or extend the list with new column names
columns_to_drop_excel.extend(additional_columns_excel) 
df_anti_join_excel = df_merge_excel[df_merge_excel['_merge'] == 'left_only'].drop(columns=columns_to_drop_excel)
df_anti_join_excel.shape[0]
# Out:
# 0

# %%
cnxn = podbc.connect("Driver={SQL Server Native Client 11.0};Server=hspmins18;Database=Isolamento_Versao_2;uid=hspmApp;pwd=SoundG@rden=1")
cursor = cnxn.cursor()
try:
    for index, row in df_resultados_inner_join.iterrows():
        # Prepare the SQL query
        sql = """
        UPDATE [Isolamento_Versao_2].[dbo].[CCIH]
        SET [ComplementoResultado] = ?
        WHERE [NumeroPedido] = ? and [Resultado] = ?;
        """
        # Execute the query with parameters
        cursor.execute(sql, (row['ComplementoResultado_x'], row['NumeroPedido'] ,row['Resultado']))
         
    # Commit all updates
    cnxn.commit()
    print("All updates were successful.")
except Exception as e:
    print("Error occurred:", e)
    cnxn.rollback()  # Roll back in case of any error
finally:
    cursor.close()
    cnxn.close()
# Out:
# All updates were successful.

# %%
df_anti_join_excel.rename(columns=lambda x: x.replace('_x', ''), inplace=True)
df_anti_join_excel
# Out:
# Empty DataFrame
# Columns: [parametroDataInicial, parametroDataFinal, ParametroUsuarioLogado, DataSistema, Clinica, NomeClinica, NumeroPedido, NomePaciente, DataNascimento, Nome, Resultado, ComplementoResultado, Ativo]
# Index: []

# %%
cnxn = podbc.connect("Driver={SQL Server Native Client 11.0};Server=hspmins18;Database=Isolamento_Versao_2;uid=hspmApp;pwd=SoundG@rden=1")
cursor = cnxn.cursor()
try:
    for index, row in df_anti_join_excel.iterrows():
        if pd.isna(row['Resultado']):
      # Prepare the SQL query
            sql = """
            INSERT INTO [dbo].[CCIH]
               (
               [parametroDataInicial]
               ,[parametroDataFinal]
               ,[ParametroUsuarioLogado]
               ,[DataSistema]
               ,[Clinica]
               ,[NomeClinica]
               ,[NumeroPedido]
               ,[NomePaciente]
               ,[DataNascimento]
               ,[Nome]
               , [Resultado]
           
          
               ,[ComplementoResultado]
               ,[Ativo])
         VALUES
               (?,?,?,?,?,?,?,?,?,?,NULL,?,'A')
            """
            # Execute the query with parameters
            cursor.execute(sql, (row['parametroDataInicial'], row['parametroDataFinal'] ,row['ParametroUsuarioLogado'],row['DataSistema'], row['Clinica'] ,row['NomeClinica'],row['NumeroPedido'], row['NomePaciente'] ,row['DataNascimento'],row['Nome'],row['ComplementoResultado'] ))
         
        else:
            # Prepare the SQL query
            sql = """
            INSERT INTO [dbo].[CCIH]
               (
               [parametroDataInicial]
               ,[parametroDataFinal]
               ,[ParametroUsuarioLogado]
               ,[DataSistema]
               ,[Clinica]
               ,[NomeClinica]
               ,[NumeroPedido]
               ,[NomePaciente]
               ,[DataNascimento]
               ,[Nome]
               ,[Resultado]
           
          
               ,[ComplementoResultado]
               ,[Ativo])
         VALUES
               (?,?,?,?,?,?,?,?,?,?,?,?,'A')
            """
            # Execute the query with parameters
            cursor.execute(sql, (row['parametroDataInicial'], row['parametroDataFinal'] ,row['ParametroUsuarioLogado'],row['DataSistema'], row['Clinica'] ,row['NomeClinica'],row['NumeroPedido'], row['NomePaciente'] ,row['DataNascimento'],row['Nome'], row['Resultado'] ,row['ComplementoResultado'] ))
         
    # Commit all updates
    cnxn.commit()
    print("All updates were successful.")
except Exception.Error as e:
    print("Error occurred:", e)
    cnxn.rollback()  # Roll back in case of any error
finally:
    cursor.close()
    cnxn.close()
# Out:
# All updates were successful.

# %%
df_anti_join_excel
# Out:
# Empty DataFrame
# Columns: [parametroDataInicial, parametroDataFinal, ParametroUsuarioLogado, DataSistema, Clinica, NomeClinica, NumeroPedido, NomePaciente, DataNascimento, Nome, Resultado, ComplementoResultado, Ativo]
# Index: []

# %%
df_anti_join_sql
# Out:
# Empty DataFrame
# Columns: [posicao, parametroDataInicial_x, parametroDataFinal_x, ParametroUsuarioLogado_x, DataSistema_x, Clinica_x, NomeClinica_x, NumeroPedido, NomePaciente_x, DataNascimento_x, Nome_x, Resultado, Prontuario, id, ComplementoResultado_x, Ativo]
# Index: []

# %%
df_resultados_inner_join
# Out:
#    parametroDataInicial_x parametroDataFinal_x ParametroUsuarioLogado_x  \
# 0              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 1              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 2              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 3              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 4              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 5              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 6              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 7              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 8              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 9              2024-06-07           2024-07-30            HENRIQLUSTOSA
# 10             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 11             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 12             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 13             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 14             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 15             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 16             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 17             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 18             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 19             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 20             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 21             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 22             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 23             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 24             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 25             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 26             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 27             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 28             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 29             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 30             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 31             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 32             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 33             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 34             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 35             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 36             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 37             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 38             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 39             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 40             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 41             2024-06-07           2024-07-30            HENRIQLUSTOSA
# 42             2024-06-07           2024-07-30            HENRIQLUSTOSA
#
#    DataSistema_x Clinica_x                  NomeClinica_x  NumeroPedido  \
# 0     2024-06-26       1PS  PRONTO SOCORRO ADULTO_1º AND       10833851
# 1     2024-07-17       10A                   10º AND_ UTI      10837803
# 2     2024-07-23       7CC        CENTRO CIRURGICO_7º AND      10829588
# 3     2024-07-23       7CC        CENTRO CIRURGICO_7º AND      10829589
# 4     2024-07-05      1PS2         PRONTO SOCORRO _2º AND      10797322
# 5     2024-06-14      1PS2         PRONTO SOCORRO _2º AND      10817972
# 6     2024-06-14       1PS  PRONTO SOCORRO ADULTO_1º AND       10817973
# 7     2024-06-25      5NEF        NEFROLOGIA_5º AND - AMB      10833479
# 8     2024-07-05       7CC        CENTRO CIRURGICO_7º AND      10829602
# 9     2024-06-29      1PS2         PRONTO SOCORRO _2º AND      10825986
# 10    2024-06-29      1PS2         PRONTO SOCORRO _2º AND      10825987
# 11    2024-06-29      1PS2         PRONTO SOCORRO _2º AND      10825988
# 12    2024-06-16       10A                   10º AND_ UTI      10819982
# 13    2024-06-28      6URO          UROLOGIA_6º AND - AMB      10835068
# 21                     UROCULTURA  ...    2024-06-19      1PS2
# 22                     UROCULTURA  ...    2024-06-28      6PRO
# 23                     UROCULTURA  ...    2024-07-03      6URO
# 24                  CULTURA GERAL  ...    2024-07-01      1UT7
# 25                     UROCULTURA  ...    2024-06-18       1PS
# 26                     UROCULTURA  ...    2024-06-12       11A
# 27                  CULTURA GERAL  ...    2024-06-23      1UT6
# 28                  CULTURA GERAL  ...    2024-07-06       1PS
# 29                  CULTURA GERAL  ...    2024-06-14       10A
# 30                  CULTURA GERAL  ...    2024-06-14       10A
# 31                     UROCULTURA  ...    2024-06-17      6URO
# 32                     UROCULTURA  ...    2024-06-17      6URO
# 33                  CULTURA GERAL  ...    2024-06-20      2ONC
# 34                  CULTURA GERAL  ...    2024-06-26      1UT7
# 35         HEMOCULTURA 2º AMOSTRA  ...    2024-06-26       11A
# 36         HEMOCULTURA 1º AMOSTRA  ...    2024-06-26       11A
# 37         HEMOCULTURA 1º AMOSTRA  ...    2024-06-23       11A
# 38         HEMOCULTURA 2º AMOSTRA  ...    2024-06-23       11A
# 39  HEMOCULTURA SANGUE DE CATETER  ...    2024-06-23       11A
# 40  HEMOCULTURA SANGUE DE CATETER  ...    2024-06-19       11A
# 41         HEMOCULTURA 1º AMOSTRA  ...    2024-06-18       11A
# 42         HEMOCULTURA 2º AMOSTRA  ...    2024-06-18       11A
#
#                     NomeClinica_y                         NomePaciente_y  \
# 0   PRONTO SOCORRO ADULTO_1º AND                        ALCIDES ERACLIDE
# 1                    10º AND_ UTI                   ARANDI LIMA DA SILVA
# 2         CENTRO CIRURGICO_7º AND  CECILIA REGINA DOS SANTOS DE OLIVEIRA
# 3         CENTRO CIRURGICO_7º AND  CECILIA REGINA DOS SANTOS DE OLIVEIRA
# 4          PRONTO SOCORRO _2º AND                CLEA APARECIDA DE SOUZA
# 5          PRONTO SOCORRO _2º AND                  DJALMA DE SOUZA BENTO
# 6   PRONTO SOCORRO ADULTO_1º AND                   DJALMA DE SOUZA BENTO
# 7         NEFROLOGIA_5º AND - AMB                 DOMINGOS JOSE COUTINHO
# 8         CENTRO CIRURGICO_7º AND                     EDNA MARINI CAMPOS
# 9          PRONTO SOCORRO _2º AND                  EDNA MARINI DE CAMPOS
# 10         PRONTO SOCORRO _2º AND                  EDNA MARINI DE CAMPOS
# 11         PRONTO SOCORRO _2º AND                  EDNA MARINI DE CAMPOS
# 12                   10º AND_ UTI                         ELISA BOYTCHUK
# 13          UROLOGIA_6º AND - AMB             ELSA BIERBAUMER DOS SANTOS
# 14                         CHOQUE                ERIVALDO PEDRO DA SILVA
# 15  PRONTO SOCORRO ADULTO_1º AND                 ERIVALDO PEDRO DA SILVA
# 16  PRONTO SOCORRO ADULTO_1º AND                 EVA DELFINO DE OLIVEIRA
# 17    9º AND_A - ENFERMARIA GERAL             LUCIANA GUEDES DE OLIVEIRA
# 18         ONCOLOGIA_4º AND - AMB        LUCIANA PAULOS DE BARROS BLOISE
# 18       1974-01-22         HEMOCULTURA 1º AMOSTRA    5409701  4497
# 19       1974-01-22                     UROCULTURA    5409701  4531
# 20       1974-01-22         HEMOCULTURA 1º AMOSTRA    5409701  4493
# 21       1942-04-05                     UROCULTURA    2220846  4504
# 22       1950-09-07                     UROCULTURA    4839056  4524
# 23       1954-03-13                     UROCULTURA   10857738  4525
# 24       1959-04-01                  CULTURA GERAL    2073690  4518
# 25       1937-03-24                     UROCULTURA    1085679  4505
# 26       1947-06-20                     UROCULTURA    1065689  4494
# 27       1957-08-07                  CULTURA GERAL    4844122  4510
# 28       1970-03-05                  CULTURA GERAL   12078689  4532
# 29       1966-05-07                  CULTURA GERAL   10482289  4500
# 30       1966-05-07                  CULTURA GERAL   10482289  4499
# 31       1944-05-16                     UROCULTURA    4388328  4511
# 32       1944-05-16                     UROCULTURA    4388328  4512
# 33       1965-04-30                  CULTURA GERAL   10830560  4513
# 34       1963-10-10                  CULTURA GERAL   12262507  4519
# 35       1948-09-08         HEMOCULTURA 2º AMOSTRA    4170734  4516
# 36       1948-09-08         HEMOCULTURA 1º AMOSTRA    4170734  4517
# 37       1948-09-08         HEMOCULTURA 1º AMOSTRA    4170734  4507
# 38       1948-09-08         HEMOCULTURA 2º AMOSTRA    4170734  4508
# 39       1948-09-08  HEMOCULTURA SANGUE DE CATETER    4170734  4509
# 40       1948-09-08  HEMOCULTURA SANGUE DE CATETER    4170734  4501
# 41       1948-09-08         HEMOCULTURA 1º AMOSTRA    4170734  4502
# 42       1948-09-08         HEMOCULTURA 2º AMOSTRA    4170734  4503
#
#                                ComplementoResultado_y Ativo
# 0   Enterococcus resistente a glicopeptideos (VRE)...     A
# 1   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 2   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 3   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 4   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 5   Enterococcus resistente a glicopeptideos (VRE)...     A
# 6   Enterococcus resistente a glicopeptideos (VRE)...     A
# 7   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 8   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 9   Cepa resistente a carbapenemicos, consultar CCIH.     A
# 10  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 11  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 12  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 13  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 14  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 15  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 16  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 17  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 18  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 19  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 20  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 21  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 22  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 23  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 24  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 25  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 26  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 27  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 28  Enterococcus resistente a glicopeptideos (VRE)...     A
# 29  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 30  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 31  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 32  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 33  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 34  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 35  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 36  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 37  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 38  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 39  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 40  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 41  Cepa resistente a carbapenemicos, consultar CCIH.     A
# 42  Cepa resistente a carbapenemicos, consultar CCIH.     A
#
# [43 rows x 26 columns]

# %%
df_anti_join_excel
# Out:
# Empty DataFrame
# Columns: [parametroDataInicial, parametroDataFinal, ParametroUsuarioLogado, DataSistema, Clinica, NomeClinica, NumeroPedido, NomePaciente, DataNascimento, Nome, Resultado, ComplementoResultado, Ativo]
# Index: []

# %%
df_anti_join_excel.size
# Out:
# 0
